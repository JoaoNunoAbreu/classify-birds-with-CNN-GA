# %%
#Used to make data more uniform across screen.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
#Import packages used here:
# for initial data exploration:
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from IPython.display import Image, display
import random
import math

#For modeling and model viewing. 
import tensorflow as tf
from keras.preprocessing.image import load_img,img_to_array,ImageDataGenerator
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model 
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Activation,Concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical #Image generator used for transformation to categorical
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras import backend, models
#from sklearn.model_selection import train_test_split  #could have used on the consolidated file.
from sklearn.metrics import confusion_matrix

from tensorflow.keras.applications import VGG16, MobileNet
#from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import preprocess_input

# %%
#This will setup my directories for all of the data files in the 100-bird-species dataset. 
BASE_DIR = 'dataset'
print('BASE_DIR contains ', os.listdir(BASE_DIR))
TRAIN_DIR = os.path.join(BASE_DIR, 'train')
VALIDATION_DIR = os.path.join(BASE_DIR, 'valid')
TEST_DIR = os.path.join(BASE_DIR, 'test')
# Out:
# BASE_DIR contains  ['valid', '.DS_Store', 'test', 'train']

# %%
#This will establish the prediction groups for the model.
CATEGORIES = os.listdir(TRAIN_DIR)
print(str(len(CATEGORIES)),'CATEGORIES are ', CATEGORIES)

Category_count = len(CATEGORIES)
# Out:
# 250 CATEGORIES are  ['RUFUOS MOTMOT', 'WHITE TAILED TROPIC', 'KOOKABURRA', 'TREE SWALLOW', 'AMERICAN REDSTART', 'EASTERN TOWEE', 'HOOPOES', 'BELTED KINGFISHER', 'CRESTED CARACARA', 'IMPERIAL SHAQ', 'VIOLET GREEN SWALLOW', 'CAPE MAY WARBLER', 'EASTERN MEADOWLARK', 'HOATZIN', 'TAIWAN MAGPIE', 'RED BELLIED PITTA', 'BARRED PUFFBIRD', 'SNOWY OWL', 'NORTHERN GOSHAWK', 'NORTHERN RED BISHOP', 'PURPLE FINCH', 'TAKAHE', 'KING VULTURE', 'SHOEBILL', 'TRUMPTER SWAN', 'BLACK-NECKED GREBE', 'AMERICAN COOT', 'PUFFIN', 'BLACKBURNIAM WARBLER', 'BROWN THRASHER', 'PALILA', 'JABIRU', 'ANNAS HUMMINGBIRD', 'CALIFORNIA GULL', 'PARUS MAJOR', 'VENEZUELIAN TROUPIAL', 'NORTHERN BALD IBIS', 'BIRD OF PARADISE', 'STRAWBERRY FINCH', 'RED HONEY CREEPER', 'RED FACED WARBLER', 'JAVAN MAGPIE', 'EMPEROR PENGUIN', 'GYRFALCON', 'EMU', 'BLACK-CAPPED CHICKADEE', 'COUCHS KINGBIRD', 'GUINEA TURACO', 'RUBY THROATED HUMMINGBIRD', 'PURPLE SWAMPHEN', 'BLACK VULTURE', 'STORK BILLED KINGFISHER', 'BALTIMORE ORIOLE', 'CASSOWARY', 'BALD EAGLE', 'CAPUCHINBIRD', 'GOLDEN CHEEKED WARBLER', 'RUFOUS KINGFISHER', 'INDIAN BUSTARD', 'ARARIPE MANAKIN', 'HORNED SUNGEM', 'CARMINE BEE-EATER', 'BLUE HERON', 'YELLOW CACIQUE', 'KIWI', 'UMBRELLA BIRD', 'EASTERN BLUEBIRD', 'EURASIAN MAGPIE', 'COMMON FIRECREST', 'CURL CRESTED ARACURI', 'CANARY', 'TOWNSENDS WARBLER', 'SAMATRAN THRUSH', 'BLACK SKIMMER', 'GLOSSY IBIS', 'YELLOW BELLIED FLOWERPECKER', 'SORA', 'RED WINGED BLACKBIRD', 'BALI STARLING', 'BARN OWL', 'SHORT BILLED DOWITCHER', 'HARPY EAGLE', 'CRESTED NUTHATCH', 'GILDED FLICKER', 'SRI LANKA BLUE MAGPIE', 'OYSTER CATCHER', 'WHITE NECKED RAVEN', 'NORTHERN CARDINAL', 'VULTURINE GUINEAFOWL', 'VERMILION FLYCATHER', 'SPANGLED COTINGA', 'HOODED MERGANSER', 'D-ARNAUDS BARBET', 'CACTUS WREN', 'NORTHERN MOCKINGBIRD', 'MASKED LAPWING', 'MALACHITE KINGFISHER', 'RED WISKERED BULBUL', 'COMMON LOON', 'PINK ROBIN', 'SCARLET IBIS', 'BLACK THROATED WARBLER', 'CALIFORNIA QUAIL', 'PHILIPPINE EAGLE', 'MIKADO  PHEASANT', 'PARADISE TANAGER', 'VARIED THRUSH', 'DARK EYED JUNCO', 'EASTERN ROSELLA', 'GAMBELS QUAIL', 'RED BEARDED BEE EATER', 'GREY PLOVER', 'GO AWAY BIRD', 'ELLIOTS  PHEASANT', 'GOLD WING WARBLER', 'CASPIAN TERN', 'CROW', 'RAINBOW LORIKEET', 'PURPLE GALLINULE', 'AMERICAN AVOCET', 'COMMON POORWILL', 'FLAME TANAGER', 'COCKATOO', 'PEREGRINE FALCON', 'NORTHERN JACANA', 'CROWNED PIGEON', 'DOWNY WOODPECKER', 'NORTHERN PARULA', 'GOULDIAN FINCH', 'GREEN JAY', 'SPOONBILL', 'LONG-EARED OWL', 'OKINAWA RAIL', 'HOUSE FINCH', 'GREATOR SAGE GROUSE', 'ROSY FACED LOVEBIRD', 'COCK OF THE  ROCK', 'ROUGH LEG BUZZARD', 'PURPLE MARTIN', 'HAWAIIAN GOOSE', 'NORTHERN FLICKER', 'MYNA', 'PAINTED BUNTIG', 'WHIMBREL', 'SMITHS LONGSPUR', 'AFRICAN CROWNED CRANE', 'HOUSE SPARROW', 'WILD TURKEY', 'RAZORBILL', 'HORNBILL', 'OSPREY', 'ROCK DOVE', 'CINNAMON TEAL', 'BLUE GROUSE', 'PEACOCK', 'MALABAR HORNBILL', 'WATTLED CURASSOW', 'BLACK FRANCOLIN', 'COMMON STARLING', 'TIT MOUSE', 'BANDED BROADBILL', 'SWINHOES PHEASANT', 'GRAY CATBIRD', 'WOOD DUCK', 'AMERICAN GOLDFINCH', 'ANHINGA', 'BLACK SWAN', 'SAND MARTIN', 'TASMANIAN HEN', 'CHUKAR PARTRIDGE', 'FRIGATE', 'TURKEY VULTURE', 'LARK BUNTING', 'RED HEADED WOODPECKER', 'RED FACED CORMORANT', 'BLACK-THROATED SPARROW', 'CUBAN TODY', 'ANTBIRD', 'STEAMER DUCK', 'GOLDEN EAGLE', 'LILAC ROLLER', 'CALIFORNIA CONDOR', 'INCA TERN', 'AMERICAN KESTREL', 'GRAY PARTRIDGE', 'FIRE TAILLED MYZORNIS', 'JAVA SPARROW', 'OCELLATED TURKEY', 'HORNED GUAN', 'QUETZAL', 'NICOBAR PIGEON', 'BEARDED BARBET', 'STRIPPED SWALLOW', 'YELLOW HEADED BLACKBIRD', 'ASIAN CRESTED IBIS', 'LEARS MACAW', 'MASKED BOOBY', 'BAY-BREASTED WARBLER', 'TOUCHAN', 'MANDRIN DUCK', 'KILLDEAR', 'GOLDEN CHLOROPHONIA', 'COMMON HOUSE MARTIN', 'HELMET VANGA', 'SCARLET MACAW', 'AMERICAN BITTERN', 'BOBOLINK', 'WILSONS BIRD OF PARADISE', 'ELEGANT TROGON', 'GOLDEN PHEASANT', 'MALLARD DUCK', 'GOLDEN PIPIT', 'AMERICAN PIPIT', 'CHIPPING SPARROW', 'PELICAN', 'NORTHERN GANNET', 'CRESTED AUKLET', 'ALBATROSS', 'BAR-TAILED GODWIT', 'INDIAN PITTA', 'BARN SWALLOW', 'COM ...

# %%
#Load an image and determine image shape for analysis.
IMAGE = load_img("dataset/train/ANNAS HUMMINGBIRD/025.jpg")
plt.imshow(IMAGE)
plt.axis("off")
plt.show()

IMAGEDATA = img_to_array(IMAGE)
SHAPE = IMAGEDATA.shape
print('Figures are ', SHAPE)
# Out:
# Figures are  (224, 224, 3)

# %%
#This will be used on training, test, and valid data
General_datagen = ImageDataGenerator(rescale=1./255, )

# %%
train_data = General_datagen.flow_from_directory(TRAIN_DIR, target_size=(224,224))
print('data groups:', len(train_data)) #Will be used to determine steps_per_epoch in my models.
Train_groups = len(train_data)
print(Train_groups)
validation_data = General_datagen.flow_from_directory(VALIDATION_DIR, target_size=(224,224),)
image_qty = len(validation_data.filenames)
print('data groups:', len(validation_data))
print('validation image qty:',str(image_qty))
Valid_groups = len(validation_data)
test_data = General_datagen.flow_from_directory(TEST_DIR, target_size=(224,224),)
print('data groups:', len(test_data))
# Out:
# Found 35215 images belonging to 250 classes.
# data groups: 1101
# 1101
# Found 1250 images belonging to 250 classes.
# data groups: 40
# validation image qty: 1250
# Found 1250 images belonging to 250 classes.
# data groups: 40

# %%
#create seperate labels for images 
def label_images2(DIR, dataset):
    label = []
    image = []
    j=0
    for i in range (0,30):
        j = random.randint(0, len(dataset.filenames))
        label.append(dataset.filenames[j].split('/')[0])
        image.append(DIR + '/' + dataset.filenames[j])
    return [label,image]

#plot the random images.
y,x = label_images2(TEST_DIR, test_data)

for i in range(0,6):
    X = load_img(x[i])
    plt.subplot(2,3,+1 + i)
    plt.axis(False)
    plt.title(y[i], fontsize=8)
    plt.imshow(X)
plt.show()

# %% [markdown]
# # -----------------------------------

# %%
backend.clear_session()
base_mobilenet = MobileNet(weights = 'imagenet', include_top = False, 
                           input_shape = SHAPE)
base_mobilenet.trainable = False # Freeze the mobilenet weights.

model = Sequential()
model.add(base_mobilenet)

model.add(Flatten()) 
model.add(Activation('relu'))
model.add(Dense(Category_count)) 
model.add(Activation('softmax'))

model.summary()

#Compile
model.compile(optimizer = tf.keras.optimizers.SGD(lr=0.001, 
                                                  momentum=0.9, nesterov=True),
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

# ------------------------------------------------------------------------------------------------------

from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard
from datetime import datetime

mc = ModelCheckpoint('best_model_projeto2.h5', monitor='val_loss', mode='min', save_best_only=True)

# ------------------------------------------------------------------------------------------------------

#fit model
history = model.fit_generator( 
    train_data, 
    steps_per_epoch = Train_groups, 
    epochs = 50,
    validation_data = validation_data,
    validation_steps = Valid_groups,
    verbose = 1,
    callbacks=[EarlyStopping(monitor = 'val_accuracy', patience = 5, 
                             restore_best_weights = True),
               ReduceLROnPlateau(monitor = 'val_loss', factor = 0.7, #0.2 to 0.5 dropped to fast 0.7
                                 patience = 2, verbose = 1),
               mc
    ]) 
                # left verbose 1 so I could see the learning rate decay
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# activation (Activation)      (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 250)               12544250
# _________________________________________________________________
# activation_1 (Activation)    (None, 250)               0
# =================================================================
# Total params: 15,773,114
# Trainable params: 12,544,250
# Non-trainable params: 3,228,864
# _________________________________________________________________
# Epoch 1/50
# 1101/1101 [==============================] - 307s 278ms/step - loss: 4.2495 - accuracy: 0.5284 - val_loss: 1.3837 - val_accuracy: 0.8504
# Epoch 2/50
# 1101/1101 [==============================] - 305s 277ms/step - loss: 0.3489 - accuracy: 0.9513 - val_loss: 0.7301 - val_accuracy: 0.9160
# Epoch 3/50
# 1101/1101 [==============================] - 317s 288ms/step - loss: 0.1054 - accuracy: 0.9831 - val_loss: 0.6699 - val_accuracy: 0.9200
# Epoch 4/50
# 1101/1101 [==============================] - 350s 318ms/step - loss: 0.0380 - accuracy: 0.9928 - val_loss: 0.5215 - val_accuracy: 0.9336
# Epoch 5/50
# 1101/1101 [==============================] - 337s 306ms/step - loss: 0.0134 - accuracy: 0.9977 - val_loss: 0.4732 - val_accuracy: 0.9376
# Epoch 6/50
# 1101/1101 [==============================] - 357s 325ms/step - loss: 0.0096 - accuracy: 0.9991 - val_loss: 0.4584 - val_accuracy: 0.9376
# Epoch 7/50
# 1101/1101 [==============================] - 389s 353ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.4644 - val_accuracy: 0.9344
# Epoch 8/50
# 1101/1101 [==============================] - 356s 323ms/step - loss: 0.0039 - accuracy: 0.9998 - val_loss: 0.5534 - val_accuracy: 0.9296
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# Epoch 9/50
# 1101/1101 [==============================] - 359s 326ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.4569 - val_accuracy: 0.9360
# Epoch 10/50
# 1101/1101 [==============================] - 362s 329ms/step - loss: 2.1588e-04 - accuracy: 0.9999 - val_loss: 0.4506 - val_accuracy: 0.9384
# Epoch 11/50
# 1101/1101 [==============================] - 362s 329ms/step - loss: 9.6182e-04 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.9384
# Epoch 12/50
# 1101/1101 [==============================] - 357s 324ms/step - loss: 2.4006e-04 - accuracy: 0.9999 - val_loss: 0.4579 - val_accuracy: 0.9352
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
# Epoch 13/50
# 1101/1101 [==============================] - 375s 340ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4510 - val_accuracy: 0.9360
# Epoch 14/50
# 1101/1101 [==============================] - 381s 346ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.4500 - val_accuracy: 0.9368
# Epoch 15/50
# 1101/1101 [==============================] - 409s 371ms/step - loss: 5.4712e-04 - accuracy: 1.0000 - val_loss: 0.4499 - val_accuracy: 0.9376

# %% [markdown]
# Não foi necessário correr as 50 epochs devido à callback EarlyStopping

# %%
#plot accuracy vs epoch
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot loss values vs epoch
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Evaluate against test data.
scores = model.evaluate(test_data, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 40/40 [==============================] - 10s 243ms/step - loss: 0.2751 - accuracy: 0.9584
# Test loss: 0.27506011724472046
# Test accuracy: 0.9584000110626221

# %%
dic=train_data.class_indices
icd={k:v for v,k in dic.items()}
def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict_classes(img)
    probability=round(np.max(model.predict_proba(img)*100),2)
    print (probability, ' % chances are there that the Bird Is',icd[answer[0]])

# %%
img="dataset/valid/BANANAQUIT/1.jpg"
pic=load_img(img,target_size=(224,224,3))
plt.imshow(pic)
output(img)
# Out:
# /Users/joaonunoabreu/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# /Users/joaonunoabreu/anaconda3/envs/myenv/lib/python3.6/site-packages/tensorflow/python/keras/engine/sequential.py:425: UserWarning: `model.predict_proba()` is deprecated and will be removed after 2021-01-01. Please use `model.predict()` instead.
#   warnings.warn('`model.predict_proba()` is deprecated and '
# 100.0  % chances are there that the Bird Is BANANAQUIT

# %%
np.save('my_history.npy',history.history)

# %%
history2=np.load('my_history.npy',allow_pickle='TRUE').item()

# %%
# Para não ter que correr o model.fit de novo
import h5py
from keras.models import load_model
model = load_model('best_model_projeto.h5')

# %%
dic=train_data.class_indices
icd={k:v for v,k in dic.items()}
def output2(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict_classes(img)
    probability=round(np.max(model.predict_proba(img)*100),2)
    return (probability,icd[answer[0]],location.replace("dataset/valid/",""))

# %% [markdown]
# # Classificação de todas as aves

# %%
import os

folder = "dataset/valid/"
paths = [os.path.join(root,filename) for root, directories, filenames in os.walk(folder) for filename in filenames]

a = []
counter = 0
for img in paths:
    pic=load_img(img,target_size=(224,224,3))
    a.append(output2(img))
    counter += 1
    if(counter % 50 == 0):
        print(f'{counter}/{len(paths)}')
# Out:
# 50/1250
# 100/1250
# 150/1250
# 200/1250
# 250/1250
# 300/1250
# 350/1250
# 400/1250
# 450/1250
# 500/1250
# 550/1250
# 600/1250
# 650/1250
# 700/1250
# 750/1250
# 800/1250
# 850/1250
# 900/1250
# 950/1250
# 1000/1250
# 1050/1250
# 1100/1250
# 1150/1250
# 1200/1250
# 1250/1250

# %% [markdown]
# ## Resultado
#
# Podemos ver abaixo uma lista cuja estrutura é definida da seguinte forma:
#
# - Chance de ser a espécie prevista
# - Espécie prevista
# - Verdadeira espécie

# %%
a_sorted = sorted(a)
print(a_sorted)
# Out:
# [(42.79, 'SWINHOES PHEASANT', 'IMPERIAL SHAQ/5.jpg'), (46.97, 'OCELLATED TURKEY', 'OCELLATED TURKEY/5.jpg'), (47.38, 'PURPLE MARTIN', 'COMMON HOUSE MARTIN/2.jpg'), (51.45, 'COMMON STARLING', 'CACTUS WREN/4.jpg'), (52.22, 'PINK ROBIN', 'ROBIN/2.jpg'), (52.24, 'NORTHERN RED BISHOP', 'YELLOW HEADED BLACKBIRD/3.jpg'), (53.03, 'RED BEARDED BEE EATER', 'RED BEARDED BEE EATER/2.jpg'), (53.53, 'TREE SWALLOW', 'SPLENDID WREN/3.jpg'), (53.7, 'BANDED BROADBILL', 'MALABAR HORNBILL/4.jpg'), (56.64, 'WILD TURKEY', 'NORTHERN BALD IBIS/3.jpg'), (56.72, 'UMBRELLA BIRD', 'CROW/5.jpg'), (56.76, 'SHOEBILL', 'NORTHERN BALD IBIS/4.jpg'), (57.72, 'COMMON FIRECREST', 'CAPE MAY WARBLER/3.jpg'), (57.8, 'MALACHITE KINGFISHER', 'MALACHITE KINGFISHER/1.jpg'), (58.85, 'BLACK THROATED WARBLER', 'NORTHERN MOCKINGBIRD/2.jpg'), (59.84, 'CASSOWARY', 'RED FACED CORMORANT/4.jpg'), (61.69, 'PINK ROBIN', 'AFRICAN FIREFINCH/4.jpg'), (64.24, 'GILDED FLICKER', 'GILDED FLICKER/5.jpg'), (65.97, 'BLACK SWAN', 'CRESTED AUKLET/5.jpg'), (66.18, 'COMMON STARLING', 'CACTUS WREN/5.jpg'), (66.61, 'GOLDEN CHEEKED WARBLER', 'RED FACED CORMORANT/3.jpg'), (66.64, 'DOWNY WOODPECKER', 'SAMATRAN THRUSH/5.jpg'), (68.84, 'CANARY', 'LARK BUNTING/1.jpg'), (69.9, 'MOURNING DOVE', 'MOURNING DOVE/3.jpg'), (70.3, 'BLACK VULTURE', 'CROW/3.jpg'), (70.51, 'BLACKBURNIAM WARBLER', 'BLACKBURNIAM WARBLER/2.jpg'), (71.51, 'SHORT BILLED DOWITCHER', 'SHORT BILLED DOWITCHER/5.jpg'), (72.24, 'INDIGO BUNTING', 'COMMON GRACKLE/1.jpg'), (72.59, 'ROCK DOVE', 'MOURNING DOVE/5.jpg'), (73.68, 'CAPUCHINBIRD', 'BROWN NOODY/1.jpg'), (74.25, 'MALLARD DUCK', 'MALLARD DUCK/1.jpg'), (74.53, 'HOUSE SPARROW', 'HOUSE SPARROW/5.jpg'), (76.33, 'MARABOU STORK', 'MARABOU STORK/3.jpg'), (77.81, 'GUINEAFOWL', 'VULTURINE GUINEAFOWL/1.jpg'), (77.9, 'MALABAR HORNBILL', 'MALABAR HORNBILL/3.jpg'), (78.22, 'PURPLE GALLINULE', 'PURPLE GALLINULE/1.jpg'), (78.82, 'GOLDEN CHLOROPHONIA', 'GOULDIAN FINCH/3.jpg'), (79.15, 'MOURNING DOVE', 'MOURNING DOVE/4.jpg'), (79.41, 'CARMINE BEE-EATER', 'CARMINE BEE-EATER/1.jpg'), (80.01, 'WHITE NECKED RAVEN', 'CROW/1.jpg'), (80.21, 'CANARY', 'PURPLE FINCH/2.jpg'), (80.53, 'D-ARNAUDS BARBET', 'ANTBIRD/2.jpg'), (82.62, 'CRESTED CARACARA', 'CALIFORNIA CONDOR/4.jpg'), (82.67, 'GOLD WING WARBLER', 'GOLD WING WARBLER/4.jpg'), (83.2, 'BANANAQUIT', 'BANANAQUIT/5.jpg'), (83.6, 'STRIPPED SWALLOW', 'STRIPPED SWALLOW/5.jpg'), (83.82, 'BALTIMORE ORIOLE', 'VENEZUELIAN TROUPIAL/5.jpg'), (83.9, 'CRESTED NUTHATCH', 'CRESTED NUTHATCH/3.jpg'), (84.05, 'SWINHOES PHEASANT', 'RING-NECKED PHEASANT/4.jpg'), (84.26, 'AMERICAN PIPIT', 'AMERICAN PIPIT/2.jpg'), (84.68, 'ROBIN', 'ROBIN/3.jpg'), (85.08, 'GOLDEN EAGLE', 'ROUGH LEG BUZZARD/1.jpg'), (85.33, 'OKINAWA RAIL', 'OKINAWA RAIL/4.jpg'), (85.63, 'BARN SWALLOW', 'BARN SWALLOW/2.jpg'), (85.67, 'HOOPOES', 'BOBOLINK/2.jpg'), (85.7, 'ROUGH LEG BUZZARD', 'YELLOW HEADED BLACKBIRD/2.jpg'), (86.18, 'YELLOW CACIQUE', 'HELMET VANGA/2.jpg'), (87.77, 'OCELLATED TURKEY', 'OCELLATED TURKEY/4.jpg'), (87.98, 'VENEZUELIAN TROUPIAL', 'VENEZUELIAN TROUPIAL/2.jpg'), (88.29, 'GREATOR SAGE GROUSE', 'GREATOR SAGE GROUSE/5.jpg'), (88.57, 'GRAY CATBIRD', 'COMMON GRACKLE/5.jpg'), (88.78, 'ELLIOTS  PHEASANT', 'ELLIOTS  PHEASANT/3.jpg'), (89.04, 'BEARDED BARBET', 'SWINHOES PHEASANT/4.jpg'), (89.55, 'TOWNSENDS WARBLER', 'TOWNSENDS WARBLER/3.jpg'), (90.25, 'PURPLE MARTIN', 'PURPLE MARTIN/3.jpg'), (90.34, 'MALLARD DUCK', 'MALLARD DUCK/4.jpg'), (90.48, 'BROWN THRASHER', 'BROWN THRASHER/5.jpg'), (90.84, 'TURKEY VULTURE', 'TURKEY VULTURE/5.jpg'), (90.95, 'ELLIOTS  PHEASANT', 'ELLIOTS  PHEASANT/4.jpg'), (91.42, 'RED FACED WARBLER', 'NORTHERN CARDINAL/4.jpg'), (91.67, 'AMERICAN BITTERN', 'AMERICAN BITTERN/2.jpg'), (91.74, 'RED BEARDED BEE EATER', 'RED BEARDED BEE EATER/3.jpg'), (91.81, 'HOUSE SPARROW', 'NORTHERN MOCKINGBIRD/3.jpg'), (92.03, 'INCA TERN', 'MASKED LAPWING/1.jpg'), (92.24, 'AMERICAN AVOCET', 'BLUE HERON/5.jpg'), (92.63, 'ROADRUNNER', 'ROADRUNNER/2.jpg'), (93.22, 'LEARS MACAW', 'KING VULTURE/2.jpg'), ...

# %% [markdown]
# Há um total de 1250 imagens de validação, 1035 delas o modelo afirmou com 100% de certeza que seriam de determinada espécie.

# %%
a = [i[0] for i in a_sorted if(i[0] == 100.0)]
print(len(a))
# Out:
# 1035

# %% [markdown]
# Das 1250 imagens de validação, o modelo avaliou corretamente 1179 (94.32%).

# %%
count = 0
for i in a_sorted:
    real_species = i[2].split("/",1)[0]
    predicted_species = i[1]
    if(real_species == predicted_species):
        count += 1

print(count)
print((count / 1250)*100)
# Out:
# 1179
# 94.32000000000001
